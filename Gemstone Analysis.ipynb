# %% [markdown]
# ##**Loading Libraries & Data**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = '/content/drive/MyDrive/Projects/Gemstone Analysis/cubic_zirconia.csv'
df = pd.read_csv(file_path)

# %% [markdown]
# ##**Exploring Data**

# %%
df.head()
# Out:
#    Unnamed: 0  carat        cut color clarity  depth  table     x     y     z  \
# 0           1   0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29  2.66
# 1           2   0.33    Premium     G      IF   60.8   58.0  4.42  4.46  2.70
# 2           3   0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12  3.78
# 3           4   0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80  2.96
# 4           5   0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43  2.65
#
#    price
# 0    499
# 1    984
# 2   6289
# 3   1082
# 4    779

# %%
df.tail()
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table     x     y  \
# 26962       26963   1.11    Premium     G     SI1   62.3   58.0  6.61  6.52
# 26963       26964   0.33      Ideal     H      IF   61.9   55.0  4.44  4.42
# 26964       26965   0.51    Premium     E     VS2   61.7   58.0  5.12  5.15
# 26965       26966   0.27  Very Good     F    VVS2   61.8   56.0  4.19  4.20
# 26966       26967   1.25    Premium     J     SI1   62.0   58.0  6.90  6.88
#
#           z  price
# 26962  4.09   5408
# 26963  2.74   1114
# 26964  3.17   1656
# 26965  2.60    682
# 26966  4.27   5166

# %%
df.shape
# Out:
# (26967, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26967 entries, 0 to 26966
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  26967 non-null  int64
#  1   carat       26967 non-null  float64
#  2   cut         26967 non-null  object
#  3   color       26967 non-null  object
#  4   clarity     26967 non-null  object
#  5   depth       26270 non-null  float64
#  6   table       26967 non-null  float64
#  7   x           26967 non-null  float64
#  8   y           26967 non-null  float64
#  9   z           26967 non-null  float64
#  10  price       26967 non-null  int64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 2.3+ MB

# %%
#Checking if there is Null data
print(df.isnull().sum())
# Out:
# Unnamed: 0      0
# carat           0
# cut             0
# color           0
# clarity         0
# depth         697
# table           0
# x               0
# y               0
# z               0
# price           0
# dtype: int64

# %% [markdown]
# In a depth column 697 records are missing.

# %%
df['cut'].unique()
# Out:
# array(['Ideal', 'Premium', 'Very Good', 'Good', 'Fair'], dtype=object)

# %%
df['color'].unique()
# Out:
# array(['E', 'G', 'F', 'D', 'H', 'J', 'I'], dtype=object)

# %%
df['clarity'].unique()
# Out:
# array(['SI1', 'IF', 'VVS2', 'VS1', 'VVS1', 'VS2', 'SI2', 'I1'],
#       dtype=object)

# %% [markdown]
# ##**Data Cleaning**

# %%
#Dropping 1st column
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
#handling missing values 
df['depth'].fillna(df['depth'].mean(), inplace=True)

# %%
print(df.isnull().sum())
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64

# %%
#checking duplicate rows
print("Number of Duplicates ",df.duplicated().sum())
# Out:
# Number of Duplicates  34

# %%
#dropping duplicate rows
df.drop_duplicates(inplace=True)

# %%
print("Number of Duplicates ",df.duplicated().sum())
# Out:
# Number of Duplicates  0

# %%
df.describe()
# Out:
#               carat         depth         table             x             y  \
# count  26933.000000  26933.000000  26933.000000  26933.000000  26933.000000
# mean       0.798010     61.745282     57.455950      5.729346      5.733102
# std        0.477237      1.393848      2.232156      1.127367      1.165037
# min        0.200000     50.800000     49.000000      0.000000      0.000000
# 25%        0.400000     61.100000     56.000000      4.710000      4.710000
# 50%        0.700000     61.800000     57.000000      5.690000      5.700000
# 75%        1.050000     62.500000     59.000000      6.550000      6.540000
# max        4.500000     73.600000     79.000000     10.230000     58.900000
#
#                   z         price
# count  26933.000000  26933.000000
# mean       3.537769   3937.526120
# std        0.719964   4022.551862
# min        0.000000    326.000000
# 25%        2.900000    945.000000
# 50%        3.520000   2375.000000
# 75%        4.040000   5356.000000
# ...

# %%
df.describe(include='object')
# Out:
#           cut  color clarity
# count   26933  26933   26933
# unique      5      7       8
# top     Ideal      G     SI1
# freq    10805   5653    6565

# %%
df.head()
# Out:
#    carat        cut color clarity  depth  table     x     y     z  price
# 0   0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29  2.66    499
# 1   0.33    Premium     G      IF   60.8   58.0  4.42  4.46  2.70    984
# 2   0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12  3.78   6289
# 3   0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80  2.96   1082
# 4   0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43  2.65    779

# %% [markdown]
# ##**Univariate Analysis**

# %%
#Pie Chart for column CUT 
df['cut'].value_counts().plot.pie(figsize=(12,6),autopct='%1.2f%%',explode=[0.01,0.01,0.01,0.01,0.05])

# %%
#Pie Chart for column Color 
df['color'].value_counts().plot.bar(figsize=(12,6),color = ['tab:blue','tab:red','tab:Purple','tab:cyan','tab:Green','Pink','Orange'])

# %%
#Pie Chart for column Color 
df['clarity'].value_counts().plot.bar(figsize=(12,6))

# %%
plt.rcParams['figure.figsize']=10,6
sns.distplot(df['depth'], color='orange')
plt.suptitle('Distribution of depth')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.rcParams['figure.figsize']=10,6
sns.distplot(df['carat'], color='blue')
plt.suptitle('Distribution of carat')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.rcParams['figure.figsize']=10,6
sns.distplot(df['table'], color='red')
plt.suptitle('Distribution of table')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.rcParams['figure.figsize']=10,6
sns.distplot(df['x'], color='orange')
plt.suptitle('Distribution of x')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.rcParams['figure.figsize']=10,6
sns.distplot(df['y'], color='blue')
plt.suptitle('Distribution of y')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.rcParams['figure.figsize']=10,6
sns.distplot(df['z'], color='red')
plt.suptitle('Distribution of z')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.rcParams['figure.figsize']=10,6
sns.distplot(df['price'], color='green')
plt.suptitle('Distribution of Price')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
print("Skewness values"'\n',df.skew())
# Out:
# Skewness values
#  carat    1.114789
# depth   -0.026422
# table    0.765805
# x        0.392290
# y        3.867764
# z        2.580665
# price    1.619116
# dtype: float64
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.

# %%
cols = ['carat','depth', 'table', 'x', 'y', 'z','price' ]
for i in cols:
    sns.boxplot(df[i],whis=1.5)
    plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...

# %% [markdown]
# ##**Bivariate Analysis**

# %%
plt.figure(figsize=(18,8))
plt.subplot(1,2,1)
sns.countplot(df['cut'])
plt.title("CountPlot of Cuts")
plt.subplot(1,2,2)
sns.barplot(y=df['price'],x=df["cut"],ci=False)
plt.title("Various cuts with price")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Various cuts with price')

# %%
plt.figure(figsize=(18,8))
plt.subplot(1,2,1)
sns.countplot(df['color'])
plt.title("CountPlot of color")
plt.subplot(1,2,2)
sns.barplot(y=df['price'],x=df["color"],ci=False)
plt.title("Various color with price")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Various color with price')

# %%
plt.figure(figsize=(18,8))
plt.subplot(1,2,1)
sns.countplot(df['clarity'])
plt.title("CountPlot of clarity")
plt.subplot(1,2,2)
sns.barplot(y=df['price'],x=df["clarity"],ci=False)
plt.title("Various clarity with price")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Various clarity with price')

# %% [markdown]
# ##**Multivariate Analysis**

# %%
plt.tight_layout()
pairplot = sns.pairplot(df,diag_kind='kde')
pairplot.fig.suptitle("PairPlot of Dataset")
plt.tight_layout()
